# %%
#Importing the necessary libraries
import pandas as pd
from scipy.stats import zscore,zmap
import numpy as np

# %%
#Loading the dataset
data = pd.read_csv('D:\\SLIIT\\3rd year 2nd sem\\Fundamentals of Data Mining\\Coding\\dpc-covid19-ita-regioni.csv')
data.head(10)
# Out:
#                   data stato  codice_regione  denominazione_regione  \
# 0  2020-02-24T18:00:00   ITA              13                Abruzzo
# 1  2020-02-24T18:00:00   ITA              17             Basilicata
# 2  2020-02-24T18:00:00   ITA              18               Calabria
# 3  2020-02-24T18:00:00   ITA              15               Campania
# 4  2020-02-24T18:00:00   ITA               8         Emilia-Romagna
# 5  2020-02-24T18:00:00   ITA               6  Friuli Venezia Giulia
# 6  2020-02-24T18:00:00   ITA              12                  Lazio
# 7  2020-02-24T18:00:00   ITA               7                Liguria
# 8  2020-02-24T18:00:00   ITA               3              Lombardia
# 9  2020-02-24T18:00:00   ITA              11                 Marche
#
#          lat       long  ricoverati_con_sintomi  terapia_intensiva  \
# 0  42.351222  13.398438                       0                  0
# 1  40.639471  15.805148                       0                  0
# ...

# %%
data.describe()
# Out:
#        codice_regione           lat          long  ricoverati_con_sintomi  \
# count    21399.000000  21399.000000  21399.000000            21399.000000
# mean        11.857143     43.046293     12.225955              500.182438
# std          6.273945      2.488839      2.659010              921.124122
# min          1.000000     38.115697      7.320149                0.000000
# 25%          7.000000     41.125596     11.121231               50.000000
# 50%         12.000000     43.616760     12.388247              190.000000
# 75%         17.000000     45.434905     13.768136              546.000000
# max         22.000000     46.499335     16.867367            12077.000000
#
#        terapia_intensiva  totale_ospedalizzati  isolamento_domiciliare  \
# count       21399.000000          21399.000000            21399.000000
# mean           49.998972            550.181410            23114.968830
# std           102.166035           1018.245539            43415.185116
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21399 entries, 0 to 21398
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   data                                 21399 non-null  object
#  1   stato                                21399 non-null  object
#  2   codice_regione                       21399 non-null  int64
#  3   denominazione_regione                21399 non-null  object
#  4   lat                                  21399 non-null  float64
#  5   long                                 21399 non-null  float64
#  6   ricoverati_con_sintomi               21399 non-null  int64
#  7   terapia_intensiva                    21399 non-null  int64
#  8   totale_ospedalizzati                 21399 non-null  int64
#  9   isolamento_domiciliare               21399 non-null  int64
#  10  totale_positivi                      21399 non-null  int64
# ...

# %%
data.isna().sum()
# Out:
# data                                       0
# stato                                      0
# codice_regione                             0
# denominazione_regione                      0
# lat                                        0
# long                                       0
# ricoverati_con_sintomi                     0
# terapia_intensiva                          0
# totale_ospedalizzati                       0
# isolamento_domiciliare                     0
# totale_positivi                            0
# variazione_totale_positivi                 0
# nuovi_positivi                             0
# dimessi_guariti                            0
# deceduti                                   0
# casi_da_sospetto_diagnostico           17996
# casi_da_screening                      17997
# totale_casi                                1
# tamponi                                    0
# casi_testati                            1154
# note                                   16328
# ...

# %%
#Dropping columns with missing values
data.dropna(axis=1,inplace=True)
data.tail(10)
# Out:
#                       data stato  codice_regione denominazione_regione  \
# 21389  2022-12-08T17:00:00   ITA              21          P.A. Bolzano
# 21390  2022-12-08T17:00:00   ITA              22           P.A. Trento
# 21391  2022-12-08T17:00:00   ITA               1              Piemonte
# 21392  2022-12-08T17:00:00   ITA              16                Puglia
# 21393  2022-12-08T17:00:00   ITA              20              Sardegna
# 21394  2022-12-08T17:00:00   ITA              19               Sicilia
# 21395  2022-12-08T17:00:00   ITA               9               Toscana
# 21396  2022-12-08T17:00:00   ITA              10                Umbria
# 21397  2022-12-08T17:00:00   ITA               2         Valle d'Aosta
# 21398  2022-12-08T17:00:00   ITA               5                Veneto
#
#              lat       long  ricoverati_con_sintomi  terapia_intensiva  \
# 21389  46.499335  11.356624                      39                  1
# ...

# %% [markdown]
# # Z Score

# %%
data['zscore_deceduti'] = zscore(data['deceduti'])
data['zscore_deceduti']
# Out:
# 0       -0.701788
# 1       -0.701788
# 2       -0.701788
# 3       -0.701788
# 4       -0.701788
#            ...
# 21394    0.969542
# 21395    0.817910
# 21396   -0.393114
# 21397   -0.626039
# 21398    1.469480
# Name: zscore_deceduti, Length: 21399, dtype: float64

# %% [markdown]
# # Z Map

# %%
zmap(data['deceduti'],data['terapia_intensiva'])
# Out:
# 0         -0.489401
# 1         -0.489401
# 2         -0.489401
# 3         -0.489401
# 4         -0.489401
#             ...
# 21394    120.453814
# 21395    109.481222
# 21396     21.847311
# 21397      4.992001
# 21398    156.631066
# Name: deceduti, Length: 21399, dtype: float64

# %% [markdown]
# # Detect Outliers

# %%
threshold = 2
data['outliers'] = np.where((data['zscore_deceduti'] - threshold > 0), True, np.where(data['zscore_deceduti'] + threshold < 0, True,False))

# %%
data.drop(data[data['outliers'] == True].index,inplace=True)

# %%
data.shape
# Out:
# (20649, 18)
